# %%
import pandas as pd

# %%
df_test.to_json('cursos_udacity_5.json')

# %%
df_test = pd.read_json('cursos_udacity_5.json')

# %%
df_test = df_test.reindex(range(74))

# %%
df_test.index = range(74)

# %%
df_test.to_json('cursos_udacity_6.json')

# %%
df_test
# Out:
#                                              headline  \
# 0   Aprenda os fundamentos de programação de manei...
# 1   No primeiro curso do Nanodegree Desenvolvedor ...
# 2   Profissionais com conhecimento estatístico est...
# 3   The Problem Solving with Analytics course prov...
# 4   Este curso é uma excelente forma de preparação...
# 5   Profissionais com conhecimento de programação ...
# 6   Profissionais com conhecimento analítico estão...
# 7   This course will introduce you to the content ...
# 8   Esse curso de Google Analytics inclui aulas de...
# 9   O GitHub é a plataforma mais conceituada para ...
# 10  Torne-se um especialista em Google Ads. Aprend...
# 11  We use websites all the time, but how does cli...
# 12  In this course you’ll get hands-on experience ...
# 13  Comece a aprender as principais habilidade exi...
# 14  Ten minutes into this class you will make your...
# 15  Learn the fundamentals of data visualization a...
# ...
